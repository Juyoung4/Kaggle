# %% [markdown]
# ### Naver Movie 데이터 세트
#
# * 데이터 전처리
# * 임베딩(CountVectorize)
# * 모델 : RandomForest

# %%
import os

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer # countvec 이용
from sklearn.model_selection import train_test_split # 데이터 셋 분할
from sklearn.ensemble import RandomForestClassifier # 모델 Random Forest 사용

# %% [markdown]
# ### [1] 데이터 세트 불러오기

# %%
BASIC_PATH = "/dataset"

# %%
DATA_CLEAN_DATA = BASIC_PATH + "/train_clean.csv"
train_data = pd.read_csv(DATA_CLEAN_DATA)

# %%
documents = list(train_data['document'])
label = list(train_data['label'])

# %%
# 결측치 확인
train_data[train_data['document'].isnull()]
# Out:
# Empty DataFrame
# Columns: [document, label]
# Index: []

# %%
print(len(documents)) # 148653
print(len(label)) # 148653
# Out:
# 148653
# 148653

# %% [markdown]
# ### [2] 임베딩(CountVectorizer)

# %%
vectorizer = CountVectorizer(analyzer = "word", max_features = 6000)

X = vectorizer.fit_transform(documents)
y = np.array(label)

# %%
print(vectorizer.get_feature_names())
# Out:
# ['ㄱㄱ', 'ㄴㄴ', 'ㄷㄷ', 'ㄷㄷㄷ', 'ㄷㄷㄷㄷ', 'ㄹㅇ', 'ㅁㅊ', 'ㅂㅅ', 'ㅅㄱ', 'ㅅㅂ', 'ㅅㅅ', 'ㅆㄹㄱ', 'ㅇㅅㅇ', 'ㅇㅇ', 'ㅇㅇㅇ', 'ㅈㄴ', 'ㅈㄹ', 'ㅉㅉ', 'ㅉㅉㅉ', 'ㅋㅋ', 'ㅋㅋㅋ', 'ㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'ㅎㄷㄷ', 'ㅎㅎ', 'ㅎㅎㅎ', 'ㅎㅎㅎㅎ', '가가', '가게', '가관', '가기', '가까이', '가깝다', '가끔', '가나', '가나다', '가난하다', '가능', '가능성', '가능하다', '가다', '가도', '가두다', '가득', '가득하다', '가든', '가라', '가르다', '가르치다', '가르침', '가리다', '가만히', '가면', '가문', '가미', '가버리다', '가볍다', '가보', '가보다', '가사', '가상하다', '가수', '가스', '가슴', '가슴속', '가시', '가시다', '가식', '가안', '가야', '가왜', '가요', '가운데', '가위', '가을', '가장', '가정', '가져다주다', '가져오다', '가족', '가족영화', '가지', '가지다', '가짜', '가치', '가치관', '가필드', '가하다', '가해자', '가히', '각각', '각본', '각색', '각성', '각심', '각인', '각자', '간간히', '간다', '간단하다', '간만', '간신히', '간의', '간절하다', '간접', '간지', '간직', '간첩', '갇히다', '갈다', '갈등', '갈리다', '갈망', '갈수', '갈수록', '감각', '감기', '감다', '감당', '감독', '감독판', '감동', '감명', '감사', '감사하다', '감상', '감성', '감수성', '감싸다', '감안', '감옥', '감우성', '감점', '감정', '감정이입', '감추다', '감탄', '감흥', '감히', '갑갑하다', '갑자기', '갑작스럽다', '강간', '강남', '강도', '강동원', '강력', '강력하다', '강렬하다', '강소라', '강수연', '강시', '강아지', '강예원', '강요', '강용석', '강우석', '강원도', '강의', '강제', '강조', '강지환', '강추', '강하다', '강혜정', '강호동', '갖다', '갖추다', '같다', '같이', '같잖다', '갚다', '개구리', '개그', '개그맨', '개꿀잼', '개념', '개다', '개도', '개독', '개떡같다', '개똥', '개막', '개망작', '개미', '개발', '개방', '개봉', '개봉관', '개봉일', '개뿔', '개성', '개연', '개운하다', '개월', '개인', '개잼', '개쩌', '개척', '개콘', '개판', '객관', '갠차다', '갱스터', '거구', '거기', '거나', '거대', '거대하다', '거도', '거들다', '거듭', '거리', '거만', '거뭐', '거부', '거북', '거북하다', '거슬리다', '거야', '거여', '거울', '거의', '거임', '거장', '거저', '거중', '거지', '거지같다', '거짓', '거짓말', '거참', '거창하다', '거치다', '거품', '걱정', '건가', '건강', '건강하다', '건너', '건달', '건담', '건데', '건드리다', '건물', '건아', '건조하다', '건지다', '걷다', '걸다', '걸레', '걸리다', '걸왜', '걸음', '걸이', '걸작', '걸치다', '검다', '검사', '검색', '겁나다', '겁니다', '것임', '겉멋', '게다', '게다가', '게로', '게리', '게뭐', '게스트', '게왜', '게이', '게임', '겠다', '겨우', '겨울', '겨울왕국', '격전', '격투', '겪다', '견디다', '견자단', '결과', '결과물', '결국', '결론', '결말', '결승전', '결정', '결제', '결코', '결투', '결합', '결혼', '결혼식', '경계', '경기', '경력', '경악', '경우', '경의', '경이', '경쟁', '경제', '경지', '경찰', '경치', '경쾌하다', '경험', '계급', '계기', '계단', '계속', '계시다', '계획', '고갈', '고개', '고고', '고급', '고기', '고난', '고뇌', '고도', '고독', '고등학교', '고등학생', '고딩', '고래', '고려', '고로', '고루', '고르다', '고릴라', '고마', '고만', '고맙다', '고문', '고민', '고발', '고백', '고본', '고생', '고서', '고소영', '고수', '고스', '고양이', '고어', '고요', '고이', '고인', '고자', '고작', '고전', '고정', '고증', '고질', '고질라', '고집', '고찰', '고치다', '고통', '고통스럽다', '고프다', '고함', '고해', '고향', '고현정', '곱다', '곱씹다', '곳곳', '공각기동대', '공간', '공감', '공개', '공격', '공군', '공기', '공룡', '공리', '공부', '공상', '공식', '공연', '공원', '공유', '공익', '공장', '공존', '공주', '공중파', '공짜', '공포', '공포물', '공포영화', '공허하다', '공효진', '과감', '과거', '과는', '과대', '과도', '과분', '과언', '과연', '과의', '과잉', '과장', '과정', '과제', '과학', '곽지민', '관객', '관객수', '관계', '관계자', '관념', '관능', '관대하다', '관람', '관람객', '관련', '관리', '관성', '관심', '관우', '관점', '관찰', '관해', '광고', '광구', '광기', '광주', '광팬', '광해', '괜찬', '괜찮다', '괜히', '괴기', '괴담', '괴롭다', '괴롭히다', '괴물', '괴상하다', '괴수', '괴수영화', '괴작', '굉장하다', '교감', '교과서', '교도소', '교묘하다', '교사', '교수', '교양', '교육', '교차', '교통사고', '교회', '교훈', '구경', '구나', '구도', '구라', '구려', '구로', '구르다', '구리', '구리다', '구림', '구만', '구매', '구멍', '구분', '구석', '구성', '구성은', '구식', '구역', '구역질', '구원', '구입', '구조', '구지', '구지성', '구해', '구혜선', '국가', '국가대표', '국내', '국민', '국뽕', '국산', '국어', '국적', '국제', '군대', '군더더기', '군데', '군인', '굳다', '굳이', '굿굿', '굿굿굿', '굿굿굿굿', '굿닥터', '굿바이', '궁금', '궁금증', '궁금하다', '권력', '권리', '권상우', '권선', '권장', '권하다', '귀가', '귀신', '귀엽다', '귀요미', '귀찮다', '귀하다', '균형', '그거', '그건', '그걸', '그것', '그게', '그나마', '그나저나', '그날', '그냥', '그녀', '그다지', '그닥', '그대', '그대로', '그동안', '그딴', '그때', '그땐', '그래도', '그래서', '그래픽', '그랬는데', '그러나', '그러니까', '그러면', '그러하다', '그럭저럭', '그런', '그런대로', '그런데', '그럴듯하다', '그렇게', '그렇다', '그렇다고', '그렇지만', '그레이', '그려지다', '그로', '그로테스크', '그룹', '그릇', '그리고', '그리다', '그리스', '그리움', '그린', '그림', '그림자', '그립다', '그만', '그만두다', '그만큼', '그만하다', '그야말로', '그이', '그저', '그중', '그지같다', '그치다', '그토록', '극단', '극도', '극복', '극본', '극영화', '극장', '극장판', ...

# %%
print(X[0].toarray())
print(len(X[0].toarray()[0])) # 6000
print(X.shape) # (148653, 6000)
# Out:
# [[0 0 0 ... 0 0 0]]
# 6000
# (148653, 6000)

# %% [markdown]
# ### [3] 데이터 세트 분할 (Train + Validation)

# %%
RANDOM_SEED = 42
TEST_SPLIT = 0.2

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=TEST_SPLIT, 
                                                  random_state=RANDOM_SEED)

# %% [markdown]
# ### [4] 모델 선언 및 훈련

# %%
forest = RandomForestClassifier(n_estimators=1000) # n_estimators- 몇개의 랜덤 트리를 만들 것인지 설정
forest.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-f4866e56ea7c> in <module>
#       1 forest = RandomForestClassifier(n_estimators=1000) # n_estimators- 몇개의 랜덤 트리를 만들 것인지 설정
# ----> 2 forest.fit(X_train, y_train)
#
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     390                     verbose=self.verbose, class_weight=self.class_weight,
#     391                     n_samples_bootstrap=n_samples_bootstrap)
# --> 392                 for i, t in enumerate(trees))
#     393
#     394             # Collect newly grown trees
#
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\joblib\parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     892             sample_weight=sample_weight,
#     893             check_input=check_input,
# --> 894             X_idx_sorted=X_idx_sorted)
#     895         return self
#     896
#
# c:\users\msi\appdata\local\programs\python\python37\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ### [5] 모델 예측(정확도 측정)

# %%
print("Accuracy : %f" % forest.score(X_val, y_val)) # score()함수 => 정확도 측정
# Accuracy : 0.856800

# %% [markdown]
# ### [6] TEST 데이터 세트로 모델 확인(예측)

# %%
TEST_CLEAN_DATA = BASIC_PATH + "/test_clean.csv"
test_data = pd.read_csv(TEST_CLEAN_DATA)
test_data.head(5)

# train때와 똑같이 임베딩 해줘야 한다(vectorizer 사용)
testDataVecs = vectorizer.fit_transform(test_data['document'])
test_predicted = forest.predict(testDataVecs)
print(test_predicted)
